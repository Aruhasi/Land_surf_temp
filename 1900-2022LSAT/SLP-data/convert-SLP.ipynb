# %%
import cfgrib
import xarray as xr

# %%
grib_file = '//work/mh0033/m301036/LSAT/Data/ERA5/mslp.mon.mean.1959-2022.2.5.grib'
ds = xr.open_dataset(grib_file, engine='cfgrib', backend_kwargs={'indexpath': ''})
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 768, latitude: 73, longitude: 144)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 1959-01-01 1959-02-01 ... 2022-12-01
#     step        timedelta64[ns] ...
#     surface     float64 ...
#   * latitude    (latitude) float64 90.0 87.5 85.0 82.5 ... -85.0 -87.5 -90.0
#   * longitude   (longitude) float64 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#     valid_time  (time) datetime64[ns] ...
# Data variables:
#     msl         (time, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-07-09T09:55 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ncl_file = '//work/mh0033/m301036/LSAT/Data/ERA5/mslp.mon.mean.1959-2022.2.5.nc'
ds.to_netcdf(ncl_file)

# %%
ds.close()
